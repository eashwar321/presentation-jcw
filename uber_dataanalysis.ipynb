# %%
# import libraries

import pandas as pd
import numpy as np

# %%
# import dataset

data= pd.read_csv("My Uber Drives - 2016.csv")

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# know your dataset

print(data) # prints only top5 and bottom5
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#print top 5 rows
print(data.head())
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
print(data.head(10))
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# ...

# %%
# print bottom 5 rows
print(data.tail)
# Out:
# <bound method NDFrame.tail of            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
print(data.tail(10))
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Kar?chi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Kar?chi      2.9  Errand/Supplies
# 1147           Kar?chi      4.6  Errand/Supplies
# 1148           Kar?chi      4.6          Meeting
# ...

# %%
# Remove the last row totals , it is not reqd

data=data.drop(data.index[1155])

# %%
data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*
# 1150           Kar?chi     0.7         Meeting
# 1151  Unknown Location     3.9  Temporary Site
# 1152  Unknown Location    16.2         Meeting
# 1153           Gampaha     6.4  Temporary Site
# 1154         Ilukwatta    48.2  Temporary Site

# %%
#print the number of rows and columns in data

data.shape # displays number of rows and columns
# Out:
# (1155, 7)

# %%
data.shape[0]
# Out:
# 1155

# %%
data.shape[1]
# Out:
# 7

# %%
# information of data

data.info() # prints information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
# start date, end date needs to be converted to date datatype
# object datatype is string

#we need to focus on datatype and missing values

#missing values

data.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150        False      False      False   False  False   False     False
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
#
# [1155 rows x 7 columns]

# %%
data.isnull().sum() #more info
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
data.dtypes #only datatypes displayed
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
data.columns #column names displayed
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1155, step=1)

# %%
# print summary of data

print(data.describe)
# Out:
# <bound method NDFrame.describe of            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
print(data.describe()) #minimum value is not -ve, that's good
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
print(data.describe(include='all'))
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*       MILES*  \
# count              1155             1155      1155   1155  1155  1155.000000
# unique             1154             1154         2    177   188          NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary          NaN
# freq                  2                2      1078    201   203          NaN
# mean                NaN              NaN       NaN    NaN   NaN    10.566840
# std                 NaN              NaN       NaN    NaN   NaN    21.579106
# min                 NaN              NaN       NaN    NaN   NaN     0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN     2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN     6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN    10.400000
# max                 NaN              NaN       NaN    NaN   NaN   310.300000
#
#        PURPOSE*
# count       653
# ...

# %%
# print start date

data['START_DATE*']
# Out:
# 0         1/1/2016 21:11
# 1          1/2/2016 1:25
# 2         1/2/2016 20:25
# 3         1/5/2016 17:31
# 4         1/6/2016 14:42
#               ...
# 1150     12/31/2016 1:07
# 1151    12/31/2016 13:24
# 1152    12/31/2016 15:03
# 1153    12/31/2016 21:32
# 1154    12/31/2016 22:08
# Name: START_DATE*, Length: 1155, dtype: object

# %%
type(data['START_DATE*'])
# Out:
# pandas.core.series.Series

# %%
# print two columns start and end date

data.loc[:]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
data.loc[:,'START_DATE*':'END_DATE*'] #: -all
# Out:
#            START_DATE*         END_DATE*
# 0       1/1/2016 21:11    1/1/2016 21:17
# 1        1/2/2016 1:25     1/2/2016 1:37
# 2       1/2/2016 20:25    1/2/2016 20:38
# 3       1/5/2016 17:31    1/5/2016 17:45
# 4       1/6/2016 14:42    1/6/2016 15:49
# ...                ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14
# 1151  12/31/2016 13:24  12/31/2016 13:42
# 1152  12/31/2016 15:03  12/31/2016 15:38
# 1153  12/31/2016 21:32  12/31/2016 21:50
# 1154  12/31/2016 22:08  12/31/2016 23:51
#
# [1155 rows x 2 columns]

# %%
# print first 20 rows of columns start and end date

data.loc[0:20,'START_DATE*':'END_DATE*']
# Out:
#         START_DATE*        END_DATE*
# 0    1/1/2016 21:11   1/1/2016 21:17
# 1     1/2/2016 1:25    1/2/2016 1:37
# 2    1/2/2016 20:25   1/2/2016 20:38
# 3    1/5/2016 17:31   1/5/2016 17:45
# 4    1/6/2016 14:42   1/6/2016 15:49
# 5    1/6/2016 17:15   1/6/2016 17:19
# 6    1/6/2016 17:30   1/6/2016 17:35
# 7    1/7/2016 13:27   1/7/2016 13:33
# 8    1/10/2016 8:05   1/10/2016 8:25
# 9   1/10/2016 12:17  1/10/2016 12:44
# 10  1/10/2016 15:08  1/10/2016 15:51
# 11  1/10/2016 18:18  1/10/2016 18:53
# 12  1/10/2016 19:12  1/10/2016 19:32
# 13   1/11/2016 8:55   1/11/2016 9:21
# 14  1/11/2016 11:56  1/11/2016 12:03
# 15  1/11/2016 13:32  1/11/2016 13:46
# 16  1/11/2016 14:30  1/11/2016 14:43
# 17  1/12/2016 12:33  1/12/2016 12:49
# 18  1/12/2016 12:53  1/12/2016 13:09
# 19  1/12/2016 14:42  1/12/2016 14:56
# 20  1/12/2016 15:13  1/12/2016 15:28

# %%
data.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
data.loc[:,['START_DATE*','CATEGORY*','MILES*']]
# Out:
#            START_DATE* CATEGORY*  MILES*
# 0       1/1/2016 21:11  Business     5.1
# 1        1/2/2016 1:25  Business     5.0
# 2       1/2/2016 20:25  Business     4.8
# 3       1/5/2016 17:31  Business     4.7
# 4       1/6/2016 14:42  Business    63.7
# ...                ...       ...     ...
# 1150   12/31/2016 1:07  Business     0.7
# 1151  12/31/2016 13:24  Business     3.9
# 1152  12/31/2016 15:03  Business    16.2
# 1153  12/31/2016 21:32  Business     6.4
# 1154  12/31/2016 22:08  Business    48.2
#
# [1155 rows x 3 columns]

# %%
data.loc[0:30,['START*','PURPOSE*','MILES*']]
# Out:
#                START*         PURPOSE*  MILES*
# 0         Fort Pierce   Meal/Entertain     5.1
# 1         Fort Pierce              NaN     5.0
# 2         Fort Pierce  Errand/Supplies     4.8
# 3         Fort Pierce          Meeting     4.7
# 4         Fort Pierce   Customer Visit    63.7
# 5     West Palm Beach   Meal/Entertain     4.3
# 6     West Palm Beach          Meeting     7.1
# 7                Cary          Meeting     0.8
# 8                Cary          Meeting     8.3
# 9             Jamaica   Customer Visit    16.5
# 10           New York          Meeting    10.8
# 11           Elmhurst          Meeting     7.5
# 12            Midtown          Meeting     6.2
# 13        East Harlem   Temporary Site     6.4
# 14  Flatiron District  Errand/Supplies     1.6
# 15            Midtown   Meal/Entertain     1.7
# 16       Midtown East   Meal/Entertain     1.9
# 17            Midtown   Meal/Entertain     1.9
# 18      Hudson Square   Meal/Entertain     4.0
# ...

# %%
# selection of data using iloc - numeric index
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data.iloc[:0,3]
# Out:
# Series([], Name: START*, dtype: object)

# %%
data.iloc[:,[2,5,6]]
# Out:
#      CATEGORY*  MILES*         PURPOSE*
# 0     Business     5.1   Meal/Entertain
# 1     Business     5.0              NaN
# 2     Business     4.8  Errand/Supplies
# 3     Business     4.7          Meeting
# 4     Business    63.7   Customer Visit
# ...        ...     ...              ...
# 1150  Business     0.7          Meeting
# 1151  Business     3.9   Temporary Site
# 1152  Business    16.2          Meeting
# 1153  Business     6.4   Temporary Site
# 1154  Business    48.2   Temporary Site
#
# [1155 rows x 3 columns]

# %%
data.iloc[:,[2,5,6]].values # converts to array
# Out:
# array([['Business', 5.1, 'Meal/Entertain'],
#        ['Business', 5.0, nan],
#        ['Business', 4.8, 'Errand/Supplies'],
#        ...,
#        ['Business', 16.2, 'Meeting'],
#        ['Business', 6.4, 'Temporary Site'],
#        ['Business', 48.2, 'Temporary Site']], dtype=object)

# %%
data.iloc[:,:-1] # first : for rows, second : for columns and except last column
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*
# 0          Fort Pierce     5.1
# 1          Fort Pierce     5.0
# 2          Fort Pierce     4.8
# ...

# %%
data.iloc[:,-1]
# Out:
# 0        Meal/Entertain
# 1                   NaN
# 2       Errand/Supplies
# 3               Meeting
# 4        Customer Visit
#              ...
# 1150            Meeting
# 1151     Temporary Site
# 1152            Meeting
# 1153     Temporary Site
# 1154     Temporary Site
# Name: PURPOSE*, Length: 1155, dtype: object

# %%
# conditional selection

# see the data where miles less than 20

data['MILES*']<10
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1150     True
# 1151     True
# 1152    False
# 1153     True
# 1154    False
# Name: MILES*, Length: 1155, dtype: bool

# %%
data[data['MILES*']<10]
# Out:
#            START_DATE*         END_DATE* CATEGORY*           START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business      Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business      Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business      Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business      Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business  West Palm Beach
# ...                ...               ...       ...              ...
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business          Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business          Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business          Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business          Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business       Katunayake
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# 1          Fort Pierce     5.0              NaN
# ...

# %%
data[data['MILES*']<10].shape[0]
# Out:
# 837

# %%
data[data['START*']=='Cary'].shape[0] #print no of rows where start = 'Cary'
# Out:
# 201

# %%
data[data['START*']=='Cary'].shape[1]
# Out:
# 7

# %%
# pass two condition

data[(data['MILES*']<10)&(data['START*']=='Cary')].shape[0]
# Out:
# 143

# %%
# print category miles start miles where miles greater than 25

data[data["MILES*"]>25][["CATEGORY*","MILES*","START*"]]
# Out:
#      CATEGORY*  MILES*            START*
# 4     Business    63.7       Fort Pierce
# 36    Business    40.2           Raleigh
# 108   Business    43.7        Katunayaka
# 232   Business   136.0            Austin
# 233   Business    30.2              Katy
# ...        ...     ...               ...
# 961   Business    43.6     Mountain View
# 979   Business    39.2              Cary
# 1088  Business   103.0        Rawalpindi
# 1089  Business    32.3  Unknown Location
# 1154  Business    48.2           Gampaha
#
# [65 rows x 3 columns]

# %%
data.loc[data["MILES*"]>25][["CATEGORY*","MILES*","START*"]]
# Out:
#      CATEGORY*  MILES*            START*
# 4     Business    63.7       Fort Pierce
# 36    Business    40.2           Raleigh
# 108   Business    43.7        Katunayaka
# 232   Business   136.0            Austin
# 233   Business    30.2              Katy
# ...        ...     ...               ...
# 961   Business    43.6     Mountain View
# 979   Business    39.2              Cary
# 1088  Business   103.0        Rawalpindi
# 1089  Business    32.3  Unknown Location
# 1154  Business    48.2           Gampaha
#
# [65 rows x 3 columns]

# %%
# create new column

# len miles - if miles <5, small, elif miles>=5 and miles<20 - normal, long

# %%
#create a new col

def func(num):
    if num<5:
        return "small journey"
    elif num>=5 and num<20:
        return "normal journey"
    else:
        return "Long journey"

# %%
data['Journey_type']=data['MILES*'].apply(func) #apply a function along an axis of the dataframe

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*    Journey_type
# 0          Fort Pierce     5.1   Meal/Entertain  normal journey
# ...

# %%
# column info
#unique data
data["CATEGORY*"].unique() #prints name of category
# Out:
# array(['Business', 'Personal'], dtype=object)

# %%
data["CATEGORY*"].nunique() # prints number of category
# Out:
# 2

# %%
#print category along number of records
data["CATEGORY*"].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
data["PURPOSE*"].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE*, dtype: int64

# %%
data["PURPOSE*"].unique()
# Out:
# array(['Meal/Entertain', nan, 'Errand/Supplies', 'Meeting',
#        'Customer Visit', 'Temporary Site', 'Between Offices',
#        'Charity ($)', 'Commute', 'Moving', 'Airport/Travel'], dtype=object)

# %%
data["PURPOSE*"].nunique()
# Out:
# 10

# %%
# pandas allows visualisation

data["PURPOSE*"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data["PURPOSE*"].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='PURPOSE*'>

# %%
data["PURPOSE*"].value_counts().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#DATA WRANGLING
#handling the missing values

data.isnull().sum()
# Out:
# START_DATE*       0
# END_DATE*         0
# CATEGORY*         0
# START*            0
# STOP*             0
# MILES*            0
# PURPOSE*        502
# Journey_type      0
# dtype: int64

# %%
# convert output in %

(data.isnull().sum()/len(data))*100
# Out:
# START_DATE*      0.000000
# END_DATE*        0.000000
# CATEGORY*        0.000000
# START*           0.000000
# STOP*            0.000000
# MILES*           0.000000
# PURPOSE*        43.463203
# Journey_type     0.000000
# dtype: float64

# %%
#handling the missing values

# create a copy of data

df1=data.copy()

# %%
# drop the null values

df1.dropna()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*    Journey_type
# 0          Fort Pierce     5.1   Meal/Entertain  normal journey
# ...

# %%
df1.isnull().sum()
# Out:
# START_DATE*       0
# END_DATE*         0
# CATEGORY*         0
# START*            0
# STOP*             0
# MILES*            0
# PURPOSE*        502
# Journey_type      0
# dtype: int64

# %%
# drop the null values permanentlyyyyy
df1.dropna(inplace = True)

# %% [markdown]
# df1.isnull().sum()

# %%
df2=data.copy()

# %%
df2
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*    Journey_type
# 0          Fort Pierce     5.1   Meal/Entertain  normal journey
# ...

# %% [markdown]
# # methods to fill missing values
#
# # missing value in numerical col - mean, median
#
# # missing values categorical col- most frequent(mode),NA

# %%
df2['PURPOSE*'].fillna('NA')
# Out:
# 0        Meal/Entertain
# 1                    NA
# 2       Errand/Supplies
# 3               Meeting
# 4        Customer Visit
#              ...
# 1150            Meeting
# 1151     Temporary Site
# 1152            Meeting
# 1153     Temporary Site
# 1154     Temporary Site
# Name: PURPOSE*, Length: 1155, dtype: object

# %%
df2['PURPOSE*'].fillna('NA', inplace = True)

# %%
df2.isnull().sum()
# Out:
# START_DATE*     0
# END_DATE*       0
# CATEGORY*       0
# START*          0
# STOP*           0
# MILES*          0
# PURPOSE*        0
# Journey_type    0
# dtype: int64

# %%
data['MILES*'].hist()
# Out:
# <AxesSubplot:>

# %%
data['MILES*'].fillna(data['MILES*'].median())
# Out:
# 0        5.1
# 1        5.0
# 2        4.8
# 3        4.7
# 4       63.7
#         ...
# 1150     0.7
# 1151     3.9
# 1152    16.2
# 1153     6.4
# 1154    48.2
# Name: MILES*, Length: 1155, dtype: float64

# %%
data['MILES*'].hist()
# Out:
# <AxesSubplot:>

# %%
data['MILES*'].fillna(data['MILES*'].median(),inplace=True)

# %%
#sort the data

data.sort_values(by=['MILES*'])
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
# 1111   12/25/2016 0:10   12/25/2016 0:14  Business            Lahore
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# ...                ...               ...       ...               ...
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
#
#                  STOP*  MILES*         PURPOSE*   Journey_type
# 420            Tribeca     0.5  Errand/Supplies  small journey
# ...

# %%
data.sort_values(by=['MILES*'],ascending=False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# ...                ...               ...       ...               ...
# 945   11/12/2016 13:46  11/12/2016 13:50  Business           Central
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*  MILES*         PURPOSE*   Journey_type
# 269       Jacksonville   310.3   Customer Visit   Long journey
# ...

# %%
# sort the data based on two columns

data.sort_values(by=['START*','MILES*'])
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*  \
# 908    11/5/2016 8:34    11/5/2016 8:43  Business          Agnew
# 910   11/5/2016 19:20   11/5/2016 19:28  Business          Agnew
# 911   11/6/2016 10:50   11/6/2016 11:04  Business          Agnew
# 906   11/4/2016 21:04   11/4/2016 21:20  Business          Agnew
# 879  10/30/2016 12:58  10/30/2016 13:18  Business         Almond
# ..                ...               ...       ...            ...
# 321   4/19/2016 17:44   4/19/2016 18:08  Business    Whitebridge
# 64     2/2/2016 13:04    2/2/2016 13:23  Business    Whitebridge
# 511    7/4/2016 17:31    7/4/2016 17:49  Business    Whitebridge
# 72     2/4/2016 18:04    2/4/2016 18:31  Business    Whitebridge
# 870  10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
#
#                   STOP*  MILES*        PURPOSE*    Journey_type
# 908         Renaissance     2.2             NaN   small journey
# ...

# %%
# sort the data based on two columns

data.sort_values(by=['START*','MILES*'],ascending=[True,False])
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*  \
# 906   11/4/2016 21:04   11/4/2016 21:20  Business          Agnew
# 911   11/6/2016 10:50   11/6/2016 11:04  Business          Agnew
# 908    11/5/2016 8:34    11/5/2016 8:43  Business          Agnew
# 910   11/5/2016 19:20   11/5/2016 19:28  Business          Agnew
# 879  10/30/2016 12:58  10/30/2016 13:18  Business         Almond
# ..                ...               ...       ...            ...
# 900   11/3/2016 13:42   11/3/2016 13:47  Business    Whitebridge
# 889   11/1/2016 17:35   11/1/2016 17:42  Business    Whitebridge
# 890   11/1/2016 19:14   11/1/2016 19:20  Business    Whitebridge
# 516    7/5/2016 16:48    7/5/2016 16:52  Business    Whitebridge
# 870  10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
#
#               STOP*  MILES*         PURPOSE*    Journey_type
# 906            Cory     4.3              NaN   small journey
# 911     Renaissance     2.4              NaN   small journey
# ...

# %%
df2.sort_values(by=['START*','MILES*'],ascending=[True,False])
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*  \
# 906   11/4/2016 21:04   11/4/2016 21:20  Business          Agnew
# 911   11/6/2016 10:50   11/6/2016 11:04  Business          Agnew
# 908    11/5/2016 8:34    11/5/2016 8:43  Business          Agnew
# 910   11/5/2016 19:20   11/5/2016 19:28  Business          Agnew
# 879  10/30/2016 12:58  10/30/2016 13:18  Business         Almond
# ..                ...               ...       ...            ...
# 900   11/3/2016 13:42   11/3/2016 13:47  Business    Whitebridge
# 889   11/1/2016 17:35   11/1/2016 17:42  Business    Whitebridge
# 890   11/1/2016 19:14   11/1/2016 19:20  Business    Whitebridge
# 516    7/5/2016 16:48    7/5/2016 16:52  Business    Whitebridge
# 870  10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
#
#               STOP*  MILES*         PURPOSE*    Journey_type
# 906            Cory     4.3               NA   small journey
# 911     Renaissance     2.4               NA   small journey
# ...

# %%
# group by

data.groupby('START*')

# %%
data.groupby('START*').count()
# Out:
#                  START_DATE*  END_DATE*  CATEGORY*  STOP*  MILES*  PURPOSE*  \
# START*
# Agnew                      4          4          4      4       4         0
# Almond                     1          1          1      1       1         0
# Apex                      17         17         17     17      17        11
# Arabi                      1          1          1      1       1         1
# Arlington                  1          1          1      1       1         0
# ...                      ...        ...        ...    ...     ...       ...
# West University            2          2          2      2       2         1
# Weston                     2          2          2      2       2         1
# Westpark Place            17         17         17     17      17         5
# Whitebridge               68         68         68     68      68        36
# Winston Salem              1          1          1      1       1         1
#
#                  Journey_type
# START*
# ...

# %%
data.groupby('START*')['CATEGORY*'].count()
# Out:
# START*
# Agnew               4
# Almond              1
# Apex               17
# Arabi               1
# Arlington           1
#                    ..
# West University     2
# Weston              2
# Westpark Place     17
# Whitebridge        68
# Winston Salem       1
# Name: CATEGORY*, Length: 177, dtype: int64

# %%
data.groupby('START_DATE*')['CATEGORY*'].count()
# Out:
# START_DATE*
# 1/1/2016 21:11     1
# 1/10/2016 12:17    1
# 1/10/2016 15:08    1
# 1/10/2016 18:18    1
# 1/10/2016 19:12    1
#                   ..
# 9/29/2016 16:13    1
# 9/30/2016 17:39    1
# 9/30/2016 20:59    1
# 9/5/2016 10:25     1
# 9/6/2016 17:49     1
# Name: CATEGORY*, Length: 1154, dtype: int64

# %%
data.groupby('START*').mean()
# Out:
#                      MILES*
# START*
# Agnew              2.775000
# Almond            15.200000
# Apex               5.341176
# Arabi             17.000000
# Arlington          4.900000
# ...                     ...
# West University    2.200000
# Weston             4.000000
# Westpark Place     2.182353
# Whitebridge        4.020588
# Winston Salem    133.600000
#
# [177 rows x 1 columns]

# %%
data.groupby('START*').sum()
# Out:
#                  MILES*
# START*
# Agnew              11.1
# Almond             15.2
# Apex               90.8
# Arabi              17.0
# Arlington           4.9
# ...                 ...
# West University     4.4
# Weston              8.0
# Westpark Place     37.1
# Whitebridge       273.4
# Winston Salem     133.6
#
# [177 rows x 1 columns]

# %%
data.groupby('START*').max()
# Out:
# C:\Users\et00823\AppData\Local\Temp\ipykernel_17372\2023865719.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data.groupby('START*').max()
#                       START_DATE*         END_DATE* CATEGORY*  \
# START*
# Agnew             11/6/2016 10:50   11/6/2016 11:04  Business
# Almond           10/30/2016 12:58  10/30/2016 13:18  Business
# Apex              8/10/2016 19:47   8/10/2016 20:02  Business
# Arabi             6/25/2016 10:50   6/25/2016 11:18  Business
# Arlington          8/2/2016 11:51    8/2/2016 12:15  Business
# ...                           ...               ...       ...
# West University   3/16/2016 18:43   3/16/2016 18:56  Business
# Weston             6/5/2016 15:57    6/5/2016 16:08  Personal
# Westpark Place    8/12/2016 18:56   8/12/2016 19:05  Personal
# ...

# %%
data.groupby('START*').min()
# Out:
# C:\Users\et00823\AppData\Local\Temp\ipykernel_17372\3840130680.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   data.groupby('START*').min()
#                       START_DATE*         END_DATE* CATEGORY*  \
# START*
# Agnew             11/4/2016 21:04   11/4/2016 21:20  Business
# Almond           10/30/2016 12:58  10/30/2016 13:18  Business
# Apex              1/29/2016 21:21   1/29/2016 21:40  Business
# Arabi             6/25/2016 10:50   6/25/2016 11:18  Business
# Arlington          8/2/2016 11:51    8/2/2016 12:15  Business
# ...                           ...               ...       ...
# West University   3/10/2016 14:39   3/10/2016 14:55  Business
# Weston             3/5/2016 12:57    3/5/2016 13:12  Business
# Westpark Place    11/2/2016 15:45   11/2/2016 15:52  Business
# ...

# %%
data.groupby('START*')['MILES*'].agg(['mean','sum','max','min','count'])
# Out:
#                        mean    sum    max    min  count
# START*
# Agnew              2.775000   11.1    4.3    2.2      4
# Almond            15.200000   15.2   15.2   15.2      1
# Apex               5.341176   90.8    9.0    1.0     17
# Arabi             17.000000   17.0   17.0   17.0      1
# Arlington          4.900000    4.9    4.9    4.9      1
# ...                     ...    ...    ...    ...    ...
# West University    2.200000    4.4    2.3    2.1      2
# Weston             4.000000    8.0    4.2    3.8      2
# Westpark Place     2.182353   37.1    4.2    1.7     17
# Whitebridge        4.020588  273.4    9.0    0.6     68
# Winston Salem    133.600000  133.6  133.6  133.6      1
#
# [177 rows x 5 columns]

# %%
data.groupby(['CATEGORY*','PURPOSE*']).count()
# Out:
#                            START_DATE*  END_DATE*  START*  STOP*  MILES*  \
# CATEGORY* PURPOSE*
# Business  Airport/Travel             3          3       3      3       3
#           Between Offices           18         18      18     18      18
#           Customer Visit           101        101     101    101     101
#           Errand/Supplies          128        128     128    128     128
#           Meal/Entertain           160        160     160    160     160
#           Meeting                  187        187     187    187     187
#           Temporary Site            50         50      50     50      50
# Personal  Charity ($)                1          1       1      1       1
#           Commute                    1          1       1      1       1
#           Moving                     4          4       4      4       4
#
#                            Journey_type
# CATEGORY* PURPOSE*
# Business  Airport/Travel              3
#           Between Offices            18
# ...

# %%
# import libraries

import pandas as pd
import numpy as np

# %%
data= pd.read_csv("My Uber Drives - 2016.csv")

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data=data.drop(data.index[1155])

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
# outlier detection
# convert datatype of col
# dummy variable
# concate and merge in data

data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data['PURPOSE*'].fillna('NA',inplace=True)

# %%
df=data.copy()

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
#1.5 IQR rule
# iqr=q3-q1
IQR=df['MILES*'].quantile(0.75)-df['MILES*'].quantile(0.25)

# %%
IQR
# Out:
# 7.5

# %%
#q1-1.5iqr

lower=df['MILES*'].quantile(0.25)-(1.5*IQR)
upper=df['MILES*'].quantile(0.75)+(1.5*IQR)

# %%
print(lower)
# Out:
# -8.35

# %%
print(upper)
# Out:
# 21.65

# %%
df[df['MILES*']<-8.35]
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
df[df['MILES*']>21.65]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 25     1/14/2016 16:29   1/14/2016 17:05  Business           Houston
# 36     1/20/2016 13:25   1/20/2016 14:19  Business           Raleigh
# 62      2/1/2016 12:10    2/1/2016 12:43  Business       Chapel Hill
# 108     2/16/2016 3:21    2/16/2016 4:13  Business        Katunayaka
# ...                ...               ...       ...               ...
# 979   11/20/2016 10:27  11/20/2016 11:32  Business              Cary
# 1088  12/21/2016 20:56  12/21/2016 23:42  Business        Rawalpindi
# 1089  12/22/2016 15:40  12/22/2016 16:38  Business  Unknown Location
# 1092  12/22/2016 17:56  12/22/2016 18:29  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 4      West Palm Beach    63.7   Customer Visit
# ...

# %%
# drop the outlier

df.drop(df[df['MILES*']>21.65].index,inplace=True)

# %%
df.shape
# Out:
# (1078, 7)

# %%
#1155 to 1078

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# handling the outliers

df1=data.copy()

# %%
df1.loc[df1['MILES*']>21.65,'MILES*']=21.65

# %%
df1[df1['MILES*']>21.65]
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
df1.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Business cases

# following percentile 10,25,70,90,95,99

# find out the above percentiles

# decide a threshold as cutoff for outlier and drop records having values more than that

# %%
data['MILES*'].quantile([0.1,0.25,0.50,0.75,0.90,0.95,0.99])
# Out:
# 0.10      1.700
# 0.25      2.900
# 0.50      6.000
# 0.75     10.400
# 0.90     17.060
# 0.95     28.100
# 0.99    134.704
# Name: MILES*, dtype: float64

# %%
data[data['MILES*']>28.100].count()
# Out:
# START_DATE*    57
# END_DATE*      57
# CATEGORY*      57
# START*         57
# STOP*          57
# MILES*         57
# PURPOSE*       57
# dtype: int64

# %%
df.drop(df[df['MILES*']>28].index,inplace=True)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# start and end date:

data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0               NA
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
# how many rides month side

df2=data.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     1155 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df2['START_DATE*']=pd.to_datetime(df2['START_DATE*'])

# %%
df2['END_DATE*']=pd.to_datetime(df2['END_DATE*'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   datetime64[ns]
#  1   END_DATE*    1155 non-null   datetime64[ns]
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     1155 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
# create a year column for start date

# %%
df2.insert(loc=2,column='year',value=df2['START_DATE*'].dt.year)

# %%
df2
# Out:
#              START_DATE*           END_DATE*  year CATEGORY*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  2016  Business
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  2016  Business
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  2016  Business
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  2016  Business
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  2016  Business
# ...                  ...                 ...   ...       ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  2016  Business
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  2016  Business
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  2016  Business
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  2016  Business
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  2016  Business
#
#                 START*             STOP*  MILES*         PURPOSE*
# 0          Fort Pierce       Fort Pierce     5.1   Meal/Entertain
# 1          Fort Pierce       Fort Pierce     5.0               NA
# ...

# %%
df2.insert(loc=3,column='month',value=df2['START_DATE*'].dt.month)

# %%
df2
# Out:
#              START_DATE*           END_DATE*  year  month CATEGORY*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  2016      1  Business
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  2016      1  Business
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  2016      1  Business
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  2016      1  Business
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  2016      1  Business
# ...                  ...                 ...   ...    ...       ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  2016     12  Business
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  2016     12  Business
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  2016     12  Business
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  2016     12  Business
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  2016     12  Business
#
#                 START*             STOP*  MILES*         PURPOSE*
# 0          Fort Pierce       Fort Pierce     5.1   Meal/Entertain
# ...

# %%
df2.head(100)
# Out:
#            START_DATE*           END_DATE*  year  month CATEGORY*  \
# 0  2016-01-01 21:11:00 2016-01-01 21:17:00  2016      1  Business
# 1  2016-01-02 01:25:00 2016-01-02 01:37:00  2016      1  Business
# 2  2016-01-02 20:25:00 2016-01-02 20:38:00  2016      1  Business
# 3  2016-01-05 17:31:00 2016-01-05 17:45:00  2016      1  Business
# 4  2016-01-06 14:42:00 2016-01-06 15:49:00  2016      1  Business
# ..                 ...                 ...   ...    ...       ...
# 95 2016-02-12 08:21:00 2016-02-12 08:42:00  2016      2  Business
# 96 2016-02-12 10:45:00 2016-02-12 10:52:00  2016      2  Business
# 97 2016-02-12 11:14:00 2016-02-12 11:35:00  2016      2  Business
# 98 2016-02-12 13:02:00 2016-02-12 13:36:00  2016      2  Business
# 99 2016-02-12 14:49:00 2016-02-12 15:06:00  2016      2  Business
#
#          START*            STOP*  MILES*         PURPOSE*
# 0   Fort Pierce      Fort Pierce     5.1   Meal/Entertain
# ...

# %%
# create a year column of start date
df2.insert(loc=4,column='Date',value=df2['START_DATE*'].dt.date)

# %%
df2
# Out:
#              START_DATE*           END_DATE*  year  month        Date  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  2016      1  2016-01-01
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  2016      1  2016-01-02
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  2016      1  2016-01-02
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  2016      1  2016-01-05
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  2016      1  2016-01-06
# ...                  ...                 ...   ...    ...         ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  2016     12  2016-12-31
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  2016     12  2016-12-31
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  2016     12  2016-12-31
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  2016     12  2016-12-31
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  2016     12  2016-12-31
#
#      CATEGORY*            START*             STOP*  MILES*         PURPOSE*
# ...

# %%
# create a year column of start date
df2.insert(loc=5,column='weekday',value=df2['START_DATE*'].dt.day_name())

# %%
df2
# Out:
#              START_DATE*           END_DATE*  year  month        Date  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  2016      1  2016-01-01
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  2016      1  2016-01-02
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  2016      1  2016-01-02
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  2016      1  2016-01-05
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  2016      1  2016-01-06
# ...                  ...                 ...   ...    ...         ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  2016     12  2016-12-31
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  2016     12  2016-12-31
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  2016     12  2016-12-31
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  2016     12  2016-12-31
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  2016     12  2016-12-31
#
#         weekday CATEGORY*            START*             STOP*  MILES*  \
# ...

# %%
df2['weekday'].value_counts()
# Out:
# Friday       206
# Tuesday      176
# Monday       174
# Thursday     154
# Saturday     150
# Sunday       148
# Wednesday    147
# Name: weekday, dtype: int64

# %%
# create a year column of start date
df2.insert(loc=6,column='hour',value=df2['START_DATE*'].dt.hour)

# %%
df2
# Out:
#              START_DATE*           END_DATE*  year  month        Date  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  2016      1  2016-01-01
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  2016      1  2016-01-02
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  2016      1  2016-01-02
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  2016      1  2016-01-05
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  2016      1  2016-01-06
# ...                  ...                 ...   ...    ...         ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  2016     12  2016-12-31
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  2016     12  2016-12-31
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  2016     12  2016-12-31
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  2016     12  2016-12-31
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  2016     12  2016-12-31
#
#         weekday  hour CATEGORY*            START*             STOP*  MILES*  \
# ...

# %%
df2['hour'].value_counts()  #98 rides booked at 15(3pm)
# Out:
# 15    98
# 17    95
# 13    94
# 18    94
# 14    89
# 16    88
# 12    77
# 11    72
# 20    71
# 19    68
# 10    65
# 9     51
# 21    51
# 8     35
# 22    31
# 23    26
# 0     19
# 7     13
# 1      5
# 5      4
# 6      4
# 3      3
# 2      2
# Name: hour, dtype: int64

# %%
df2.to_csv('Uber daw data.csv',index=False)

# %%
dy= pd.read_csv("Uber daw data.csv")

# %%
dy
# Out:
#               START_DATE*            END_DATE*  year  month        Date  \
# 0     2016-01-01 21:11:00  2016-01-01 21:17:00  2016      1  2016-01-01
# 1     2016-01-02 01:25:00  2016-01-02 01:37:00  2016      1  2016-01-02
# 2     2016-01-02 20:25:00  2016-01-02 20:38:00  2016      1  2016-01-02
# 3     2016-01-05 17:31:00  2016-01-05 17:45:00  2016      1  2016-01-05
# 4     2016-01-06 14:42:00  2016-01-06 15:49:00  2016      1  2016-01-06
# ...                   ...                  ...   ...    ...         ...
# 1150  2016-12-31 01:07:00  2016-12-31 01:14:00  2016     12  2016-12-31
# 1151  2016-12-31 13:24:00  2016-12-31 13:42:00  2016     12  2016-12-31
# 1152  2016-12-31 15:03:00  2016-12-31 15:38:00  2016     12  2016-12-31
# 1153  2016-12-31 21:32:00  2016-12-31 21:50:00  2016     12  2016-12-31
# 1154  2016-12-31 22:08:00  2016-12-31 23:51:00  2016     12  2016-12-31
#
#         weekday  hour CATEGORY*            START*             STOP*  MILES*  \
# ...
